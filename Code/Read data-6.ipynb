# %%
import numpy as np
import pandas as pd

import imageio

import matplotlib.pyplot as plt
# %matplotlib inline

import os

# %%
image_path = '/Users/Techno Link/Desktop/810/ايمان٢/e/emanhajji/p5/Self-driving-cars-main/Code/dataA/dataA/CameraRGB/'

# %%
image_path = '/Users/Techno Link/Desktop/810/ايمان٢/e/emanhajji/p5/Self-driving-cars-main/Code/dataA/dataA/CameraRGB/'
mask_path='/Users/Techno Link/Desktop/810/ايمان٢/e/emanhajji/p5/Self-driving-cars-main/Code/dataA/dataA/CameraSeg/'

image_list = os.listdir(image_path)
mask_list = os.listdir(mask_path)
image_list = [image_path+i for i in image_list]
mask_list = [mask_path+i for i in mask_list]

# %%
image_list
# Out:
# ['/Users/Techno Link/Desktop/810/ايمان٢/e/emanhajji/p5/Self-driving-cars-main/Code/dataA/dataA/CameraRGB/02_00_000.png',
#  '/Users/Techno Link/Desktop/810/ايمان٢/e/emanhajji/p5/Self-driving-cars-main/Code/dataA/dataA/CameraRGB/02_00_001.png',
#  '/Users/Techno Link/Desktop/810/ايمان٢/e/emanhajji/p5/Self-driving-cars-main/Code/dataA/dataA/CameraRGB/02_00_010.png',
#  '/Users/Techno Link/Desktop/810/ايمان٢/e/emanhajji/p5/Self-driving-cars-main/Code/dataA/dataA/CameraRGB/02_00_011.png',
#  '/Users/Techno Link/Desktop/810/ايمان٢/e/emanhajji/p5/Self-driving-cars-main/Code/dataA/dataA/CameraRGB/02_00_020.png',
#  '/Users/Techno Link/Desktop/810/ايمان٢/e/emanhajji/p5/Self-driving-cars-main/Code/dataA/dataA/CameraRGB/02_00_021.png',
#  '/Users/Techno Link/Desktop/810/ايمان٢/e/emanhajji/p5/Self-driving-cars-main/Code/dataA/dataA/CameraRGB/02_00_030.png',
#  '/Users/Techno Link/Desktop/810/ايمان٢/e/emanhajji/p5/Self-driving-cars-main/Code/dataA/dataA/CameraRGB/02_00_031.png',
# ...

# %%
N = 0
img = imageio.imread(image_list[N])
mask = imageio.imread(mask_list[N])
mask = np.array([max(mask[i, j]) for i in range(mask.shape[0]) for j in range(mask.shape[1])]).reshape(img.shape[0], img.shape[1])

fig, arr = plt.subplots(1, 2, figsize=(14, 10))
arr[0].imshow(img)
arr[0].set_title('Image')
arr[1].imshow(mask, cmap='Paired')
arr[1].set_title('Segmentation')
# Out:
# Text(0.5, 1.0, 'Segmentation')

# %%
# !pip install segmentation-models-pytorch
# Out:
# ...
#   Created wheel for efficientnet-pytorch: filename=efficientnet_pytorch-0.6.3-py3-none-any.whl size=12419 sha256=adb6940d166b6a0db2d72aa700a5f6b380808548dd2f2023d2d7614fb52aae53
#   Stored in directory: c:\users\techno link\appdata\local\pip\cache\wheels\6b\48\d7\9a3ea4072e0d735f895d5e58f9a679903dcb4e90a55418955b
# ...
#   Created wheel for pretrainedmodels: filename=pretrainedmodels-0.7.4-py3-none-any.whl size=60963 sha256=9629062eb78f09e236c7251292812b2c843c8ede2a208e684fb2043a555999ba
#   Stored in directory: c:\users\techno link\appdata\local\pip\cache\wheels\ed\fa\b9\5c82b59d905f95542a192b883c0cc0082407ea2f54beb2f9e6
# Successfully built efficientnet-pytorch pretrainedmodels
# ...

# %%
# # Create Lists of images and masks paths
# path = '/Users/Techno Link/Desktop/810/ايمان٢/e/emanhajji/p5/Self-driving-cars-main/Code/dataA/dataA/CameraRGB/'
# images_path = [path + 'data' + i + '/' + 'data' + i + '/' + 'CameraRGB' for i in ['A', 'B', 'C', 'D', 'E']]
# masks_path = [path + 'data' + i + '/' + 'data' + i + '/' + 'CameraSeg' for i in ['A', 'B', 'C', 'D', 'E']]

# %%
#image_list[:10]

# %%
# def load_image(path):
#     img=cv2.imread(path)
#     img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
#     X=img[:,:256,:]
#     Y=img[:,256:,:]
#     return X,Y

# %%
def return_paths(path):
    X = []
    for i in sorted(path):
        g = sorted(os.listdir(i))
        for j in g:
            X.append(i + ' / ' + j)
    return X

# %%
X = return_paths(image_path)
Y = return_paths(mask_path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-58-65db04976262> in <module>
# ----> 1 X = return_paths(image_path)
#       2 Y = return_paths(mask_path)
#
# <ipython-input-55-d207fc28e4b2> in return_paths(path)
#       2     X = []
#       3     for i in sorted(path):
# ----> 4         g = sorted(os.listdir(i))
#       5         for j in g:
#       6             X.append(i + ' / ' + j)
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: ' '

# %%
images_path = [path + 'data' + i + '/' + 'data' + i + '/' + 'CameraRGB' for i in ['A', 'B', 'C', 'D', 'E']]
masks_path = [path + 'data' + i + '/' + 'data' + i + '/' + 'CameraSeg' for i in ['A', 'B', 'C', 'D', 'E']]

# %%
import numpy as np
import pandas as pd
import tensorflow as tf 
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Model 
from tensorflow.keras.layers import Conv2D, concatenate, Activation, MaxPooling2D, UpSampling2D, Input, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
import cv2
import matplotlib.pyplot as plt
import random
import os
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-62-f0295a044b51> in <module>
#       1 import numpy as np
#       2 import pandas as pd
# ----> 3 import tensorflow as tf
#       4 from sklearn.model_selection import train_test_split
#       5 from tensorflow.keras.models import Model
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
conda create -n tf tensorflow

# %%
train_image_paths, val_image_paths, train_mask_paths, val_mask_paths 
= train_test_split(image_paths, mask_paths, train_size=0.8, random_state=0)

# %%
validation_image_paths, test_image_paths, validation_mask_paths, test_mask_paths = train_test_split(val_image_paths, val_mask_paths, train_size = 0.80, random_state=0)

print(f'There are {len(train_image_paths)} images in the Training Set')
print(f'There are {len(validation_image_paths)} images in the Validation Set')
print(f'There are {len(test_image_paths)} images in the Test Set')
